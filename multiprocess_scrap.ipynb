# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time
import pandas as pd
from multiprocessing import Process, Queue, Manager


class RecursiveWebScraper:
    def __init__(self, base_url, delay=1, max_depth=2, skip_domains=None, num_workers=4):
        self.base_url = base_url
        self.delay = delay
        self.max_depth = max_depth
        self.num_workers = num_workers
        self.domain = urlparse(base_url).netloc
        self.skip_domains = skip_domains or []
        self.url_file = "To_scrape.txt"
        self.url_done = "Scraped.txt"

    def scrape(self, url, depth, visited_urls, results, queue):
        if depth == 0:
            return
        if url in visited_urls:
            return

        print(f"Scraping: {url} | Depth: {self.max_depth - depth + 1}")
        visited_urls.append(url)

        try:
            response = requests.get(url)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Failed to fetch {url}: {e}")
            return

        soup = BeautifulSoup(response.text, 'html.parser')
        results[url] = self.format_content_as_markdown(url, soup)

        # Save the URL to the completed list
        with open(self.url_done, "a+") as file:
            file.write(f"{url}\n")

        # Extract and enqueue links for further scraping
        for link_tag in soup.find_all('a', href=True):
            full_url = urljoin(url, link_tag['href'])
            if self.is_valid_url(full_url, visited_urls):
                queue.put((full_url, depth - 1))
                time.sleep(self.delay)

    def is_valid_url(self, url, visited_urls):
        parsed_url = urlparse(url)
        if parsed_url.netloc != self.domain:
            return False
        for skip_domain in self.skip_domains:
            if url.startswith(skip_domain):
                return False
        return url not in set(visited_urls)

    def format_content_as_markdown(self, url, soup):
        markdown = [f"# {soup.title.string.strip() if soup.title else url}"]

        for tag in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'p', 'ul', 'li', 'div']):
            if tag.name in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
                level = int(tag.name[1])
                markdown.append(f"{'#' * level} {self.process_inline_links(tag)}")
            elif tag.name == 'p':
                markdown.append(self.process_inline_links(tag))
            elif tag.name == 'ul':
                for li in tag.find_all('li'):
                    markdown.append(f"- {self.process_inline_links(li)}")
            elif tag.name == 'div' and 'highlight-solidity' in tag.get('class', []):
                pre_tag = tag.find('pre')
                if pre_tag:
                    code = pre_tag.get_text(strip=False)
                    markdown.append(f"```solidity\n{code}\n```")

        return "\n\n".join(markdown)

    def process_inline_links(self, tag):
        text = ""
        for content in tag.contents:
            if content.name == 'a' and content.get('href'):
                link_text = content.get_text(strip=True)
                href = content['href']
                full_url = urljoin(self.base_url, href)
                with open(self.url_file, "a+") as file:
                    file.write(f"{full_url}\n")
                text += f"[{link_text}]({full_url})"
            elif isinstance(content, str):
                text += content
        return text.strip()

    def start_scraping(self):
        manager = Manager()
        visited_urls = manager.list()  # Use a list instead of set
        results = manager.dict()
        queue = Queue()

        # Initialize the queue with the base URL
        queue.put((self.base_url, self.max_depth))

        # Create worker processes
        workers = [
            Process(target=self.worker, args=(visited_urls, results, queue))
            for _ in range(self.num_workers)
        ]

        # Start all workers
        for worker in workers:
            worker.start()

        # Wait for all workers to complete
        for worker in workers:
            worker.join()

        # Save results after scraping
        self.save_results(results)


    def worker(self, visited_urls, results, queue):
        while not queue.empty():
            url, depth = queue.get()
            self.scrape(url, depth, visited_urls, results, queue)

    def save_results(self, filename="scraped_data.txt"):
        """Save the scraped results to a Markdown file."""
        with open(filename, "w", encoding="utf-8") as file:
            for url, content in self.results.items():
                new_content = ""
                lines = content.split("\n")
                for  line in lines:
                    print(len(line.split(" ")), len(line), line)
                    if len(line.split(" ")) > 0 and len(line) > 0:
                        new_content += line + "\n"
                # print(len(new_content))
                file.write(f"URL: {url}\n\n{new_content}\n\n{'-' * 80}\n\n")
        print(f"Scraped data saved to {filename}")

    def results_df(self):
        """Return the scraped results as a Pandas DataFrame."""
        return pd.DataFrame(self.results.items(), columns=["URL", "Content"])

# %%
base_url = "https://docs.soliditylang.org/en/v0.8.28/"
skip_domains = [
    "https://soliditylang.org/blog",
    # "https://docs.soliditylang.org/en"
]

scraper = RecursiveWebScraper(base_url, delay=1, max_depth=4, skip_domains=skip_domains, num_workers=1500)
scraper.start_scraping()  #
# Out:
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ | Depth: 1
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/index.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#a-simple-smart-contract | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#voting | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/layout-of-source-files.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#storage-example | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#versioning | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#subcurrency-example | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#possible-improvements | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#state-variables | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#blockchain-basics | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#remix | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/types.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#functions | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#blind-auction | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#ether-units | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#transactions | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#npm-node-js | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#simple-open-auction | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#blocks | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#time-units | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#id2 | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#function-modifiers | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#index-6 | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#docker | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/control-structures.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#linux-packages | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#events | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#safe-remote-purchase | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#errors | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#special-variables-and-functions | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#overview | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#macos-packages | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#micropayment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#accounts | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#block-and-transaction-properties | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#creating-and-verifying-signatures | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#struct-types | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#index-8 | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/assembly.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#static-binaries | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#creating-the-signature | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#building-from-source | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#abi-encoding-and-decoding-functions | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/structure-of-a-contract.html#enum-types | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#gas | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#members-of-bytes | Depth: 3Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#what-to-sign | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#prerequisites-all-operating-systems | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/cheatsheet.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#storage-transient-storage-memory-and-the-stack | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#packing-arguments | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#minimum-compiler-versions | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#members-of-string | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/grammar.html | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#calldata-returndata-and-code | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#recovering-the-message-signer-in-solidity | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#recovering-the-message-signer-in-solidity | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#creating-contracts | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#prerequisites-macos | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#error-handling | Depth: 3
#
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#error-handling | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#instruction-set | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#extracting-the-signature-parameters | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#prerequisites-windows | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#message-calls | Depth: 3Scraping: https://docs.soliditylang.org/en/v0.8.28/using-the-compiler.html | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#visibility-and-getters | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#clone-the-repository | Depth: 3Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#mathematical-and-cryptographic-functions | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/analysing-compilation-output.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#computing-the-message-hash | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#delegatecall-and-libraries | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#members-of-address-types | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#the-full-contract | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#command-line-build | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#logs | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#writing-a-simple-payment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#state-variable-visibility | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#cmake-options | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/layout_in_storage.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#contract-related | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#what-is-a-payment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#smt-solvers | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/layout_in_memory.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#function-visibility | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#create | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#create | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#opening-the-payment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#type-information | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#the-version-string-in-detail | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/layout_in_calldata.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#getter-functions | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#deactivate-and-self-destruct | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#deactivate-and-self-destruct | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/units-and-global-variables.html#reserved-keywords | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#making-payments | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#precompiled-contracts | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/installing-solidity.html#important-information-about-versioning | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#function-modifiers | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/variable_cleanup.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#closing-the-payment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#closing-the-payment-channel | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/source_mappings.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#transient-storage | Depth: 3
# Failed to fetch https://docs.soliditylang.org/en/v0.8.28/introduction-to-smart-contracts.html#transactions: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#channel-expiration | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#composability-of-smart-contracts-and-the-caveats-of-transient-storage | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/internals/optimizer.html | Depth: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       2 skip_domains = [
#       3     "https://soliditylang.org/blog",
#       4     # "https://docs.soliditylang.org/en"
#       5 ]
#       7 scraper = RecursiveWebScraper(base_url, delay=1, max_depth=4, skip_domains=skip_domains, num_workers=1500)
# ----> 8 scraper.start_scraping()  #
#
# Cell In[1], line 110, in RecursiveWebScraper.start_scraping(self)
#     108 # Start all workers
#     109 for worker in workers:
# --> 110     worker.start()
#     112 # Wait for all workers to complete
#     113 for worker in workers:
#
# File ~/miniconda3/envs/pyano/lib/python3.11/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/miniconda3/envs/pyano/lib/python3.11/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/miniconda3/envs/pyano/lib/python3.11/multiprocessing/context.py:281, in ForkProcess._Popen(process_obj)
#     278 @staticmethod
#     279 def _Popen(process_obj):
#     280     from .popen_fork import Popen
# --> 281     return Popen(process_obj)
#
# File ~/miniconda3/envs/pyano/lib/python3.11/multiprocessing/popen_fork.py:16, in Popen.__init__(self, process_obj)
#      15 def __init__(self, process_obj):
# ---> 16     util._flush_std_streams()
#      17     self.returncode = None
#      18     self.finalizer = None
#
# File ~/miniconda3/envs/pyano/lib/python3.11/multiprocessing/util.py:438, in _flush_std_streams()
#     436 def _flush_std_streams():
#     437     try:
# --> 438         sys.stdout.flush()
#     439     except (AttributeError, ValueError):
#     440         pass
#
# File ~/miniconda3/envs/pyano/lib/python3.11/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~/miniconda3/envs/pyano/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniconda3/envs/pyano/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#id3 | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/abi-spec.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#constant-and-immutable-state-variables | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/metadata.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html#semantic-only-changes | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/security-considerations.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#verifying-payments | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#verifying-payments | Depth: 3
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#verifying-payments | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#constant | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html#internals | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/bugs.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/solidity-by-example.html#modular-contracts | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#immutable | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html#internal-function-pointers | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/050-breaking-changes.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#functions | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#function-parameters-and-return-variables | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/ir-breaking-changes.html#cleanup | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/060-breaking-changes.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#function-parameters | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/070-breaking-changes.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#return-variables | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/080-breaking-changes.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/080-breaking-changes.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#returning-multiple-values | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/natspec-format.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#state-mutability | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/smtchecker.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#view-functions | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/yul.html | Depth: 2
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#special-functions | Depth: 4Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#pure-functions | Depth: 4
#
# Scraping: https://docs.soliditylang.org/en/v0.8.28/path-resolution.html | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#receive-ether-function | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/common-patterns.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/style-guide.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#fallback-function | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/resources.html | Depth: 3
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#function-overloading | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#overload-resolution-and-argument-matching | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#events | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#members-of-events | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#example | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#additional-resources-for-understanding-events | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#custom-errors | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#members-of-errors | Depth: 4
# Scraping: https://docs.soliditylang.org/en/v0.8.28/contracts.html#inheritance | Depth: 4
